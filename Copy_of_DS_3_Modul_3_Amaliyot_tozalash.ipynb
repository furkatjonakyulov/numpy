# %% [markdown]
# <a href="https://colab.research.google.com/github/furkatjonakyulov/numpy/blob/main/Copy_of_DS_3_Modul_3_Amaliyot_tozalash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # **DATA SCIENCE VA SUN'IY INTELLEKT PRAKTIKUM**
#
# ## 3.2 Ma'lumotlarni tayyorlash
#
# # **AMALIYOT**
# ## Ma'lumotlarga ishlov berish

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mukhammad-irmatov/health_dataset/main/healt_info.csv")
df
# Out:
#            Sno  AGE     SEX CASTE_NAME CATEGORY_CODE  \
# 0            1   56  Female         BC            M6
# 1            2   37    Male         BC            M6
# 2            3   50    Male         BC            M6
# 3            4   45    Male         BC            M6
# 4            5   54    Male         BC            M6
# ...        ...  ...     ...        ...           ...
# 335389  335390   65    Male         SC            S3
# 335390  335391   54  Female         OC           S12
# 335391  335392   19  Female         SC           S12
# 335392  335393   50    Male         BC            S9
# 335393  335394   46  Female         SC           S12
#
#                    CATEGORY_NAME SURGERY_CODE  \
# 0                     NEPHROLOGY         M6.5
# 1                     NEPHROLOGY         M6.5
# 2                     NEPHROLOGY         M6.5
# 3                     NEPHROLOGY         M6.5
# 4                     NEPHROLOGY         M6.5
# ...                          ...          ...
# 335389    OPHTHALMOLOGY  SURGERY         SU66
# 335390          MEDICAL ONCOLOGY      S12.1.4
# 335391          MEDICAL ONCOLOGY     S12.28.1
# 335392  GENITO URINARY SURGERIES       S9.3.4
# 335393          MEDICAL ONCOLOGY      S12.2.1
#
#                                                   SURGERY  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         VILLAGE   MANDAL_NAME  ...        CLAIM_DATE  \
# 0                        Lolugu       Ponduru  ...  22-03-2017 20:25
# 1                     Borivanka        Kaviti  ...  22-03-2017 20:25
# 2                   Kapasakuddi        Kaviti  ...  22-03-2017 20:25
# 3                   Telikipenta   Sarubujjili  ...  22-03-2017 20:25
# 4                 Thandemvalasa    Srikakulam  ...  22-03-2017 20:25
# ...                         ...           ...  ...               ...
# 335389             Chintalapudi        Ponnur  ...  04-08-2017 21:23
# 335390  Udayagiri @ Kondayapale     Udayagiri  ...  02-08-2017 19:11
# 335391                  Vinduru         Gudur  ...  04-10-2017 19:46
# 335392                Duppituru  Atchutapuram  ...  04-08-2017 20:59
# 335393             Ananthavaram  Mummidivaram  ...  09-08-2017 19:43
#
#        CLAIM_AMOUNT                                          HOSP_NAME  \
# 0             11000            Rims Govt. General Hospital, Srikakulam
# 1             11000            Rims Govt. General Hospital, Srikakulam
# 2             11500            Rims Govt. General Hospital, Srikakulam
# 3             11000            Rims Govt. General Hospital, Srikakulam
# 4             11000            Rims Govt. General Hospital, Srikakulam
# ...             ...                                                ...
# 335389        23320                                Sankar Eye Hospital
# 335390         7140  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...
# 335391         5000                                    M.N.J.Hospitals
# 335392        25000             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL
# 335393         2040  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...
#
#        HOSP_TYPE   HOSP_DISTRICT      SURGERY_DATE    DISCHARGE_DATE  \
# 0              G      Srikakulam  06-08-2013 00:00  07-09-2013 00:00
# 1              G      Srikakulam  08-08-2013 00:00  09-09-2013 00:00
# 2              G      Srikakulam  15-08-2013 00:00  18-10-2013 00:00
# 3              G      Srikakulam  24-08-2013 00:00  27-09-2013 00:00
# 4              G      Srikakulam  31-08-2013 00:00  02-10-2013 00:00
# ...          ...             ...               ...               ...
# 335389         C          Guntur  09-06-2017 00:00  10-06-2017 00:00
# 335390         C       Hyderabad  06-06-2017 00:00  06-06-2017 00:00
# 335391         G       Hyderabad  09-06-2017 00:00  10-06-2017 00:00
# 335392         C  Vishakhapatnam  06-06-2017 00:00  10-06-2017 00:00
# 335393         C   East Godavari  07-06-2017 00:00  07-06-2017 00:00
#
#        Mortality Y / N MORTALITY_DATE SRC_REGISTRATION
# 0                   NO            NaN                D
# 1                   NO            NaN                D
# 2                   NO            NaN                D
# 3                   NO            NaN                D
# 4                   NO            NaN                D
# ...                ...            ...              ...
# 335389              NO            NaN                D
# 335390              NO            NaN                D
# 335391              NO            NaN                D
# 335392              NO            NaN                D
# 335393              NO            NaN               MC
#
# [335394 rows x 23 columns]

# %% [markdown]
# Bu dataset sug'urta kompaniyasining real ma'lumotlardan tuzilgan. Bu datasetda 480000 qator sug'urta ma'lumotlar tashkil topgan.
# Quyida datasetning ba'zi ustunlari haqida qisqacha ma'lumot
#
# *   Sno = seriya raqami
# *   AGE = yoshi
# *   SEX = jinsi (female = ayol, male = erkak)
# *   CASTE_NAME = kasta nomi (Hindistonda har bir inson ma'lum bir kastaga oid bo'ladi)
# *   CATEGORY_CODE = kategoriya kodi
# *   CATEGORY_Name = kategoriya nomi
# *   SURGERY_CODE = operatsiya kodi
# *   Mandal_Name = mandal nomlanishi ya'ni familiyasi desak ham bo'ladi
# *   Mortality Y/N = vafot etgan yoki vafot etmaganligi
# *   MORTALITY_DATE = qachon vafot etganligi

# %% [markdown]
# ### **1-mashq**. Datasetdagi barcha takrorlangan qatorlar sonini toping

# %%
# Javobni shuyerga yozing

sum(df.duplicated())
# Out:
# 0

# %%
#@title **To'g'ri javob**
sum(df.duplicated())
# Out:
# 0

# %% [markdown]
# #### **2-mashq**. Datasetdagi quyidagi ustunlar o'chirib yuborilsin:<br>
# *   Sno
# *   CATEGORY_CODE
# *   SURGERY_CODE
# *   MANDAL_NAME
# *   DISTRICT_NAME
# *   HOSP_DISTRICT
# <BR>

# %%
# Javobni shuyerga yozing
df.drop(['Sno','CATEGORY_CODE','SURGERY_CODE','MANDAL_NAME','DISTRICT_NAME','HOSP_DISTRICT'],axis='columns',inplace=True)
df
# Out:
#         AGE     SEX CASTE_NAME             CATEGORY_NAME  \
# 0        56  Female         BC                NEPHROLOGY
# 1        37    Male         BC                NEPHROLOGY
# 2        50    Male         BC                NEPHROLOGY
# 3        45    Male         BC                NEPHROLOGY
# 4        54    Male         BC                NEPHROLOGY
# ...     ...     ...        ...                       ...
# 335389   65    Male         SC    OPHTHALMOLOGY  SURGERY
# 335390   54  Female         OC          MEDICAL ONCOLOGY
# 335391   19  Female         SC          MEDICAL ONCOLOGY
# 335392   50    Male         BC  GENITO URINARY SURGERIES
# 335393   46  Female         SC          MEDICAL ONCOLOGY
#
#                                                   SURGERY  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         VILLAGE      PREAUTH_DATE  PREAUTH_AMT  \
# 0                        Lolugu  03-08-2013 20:38        12500
# 1                     Borivanka  06-08-2013 07:26        12500
# 2                   Kapasakuddi  09-08-2013 18:30        12500
# 3                   Telikipenta  24-08-2013 19:37        12500
# 4                 Thandemvalasa  28-08-2013 17:03        12500
# ...                         ...               ...          ...
# 335389             Chintalapudi  08-06-2017 06:40        23320
# 335390  Udayagiri @ Kondayapale  05-06-2017 22:35         7140
# 335391                  Vinduru  06-06-2017 06:13         5000
# 335392                Duppituru  05-06-2017 23:37        25000
# 335393             Ananthavaram  06-06-2017 23:02         2040
#
#               CLAIM_DATE  CLAIM_AMOUNT  \
# 0       22-03-2017 20:25         11000
# 1       22-03-2017 20:25         11000
# 2       22-03-2017 20:25         11500
# 3       22-03-2017 20:25         11000
# 4       22-03-2017 20:25         11000
# ...                  ...           ...
# 335389  04-08-2017 21:23         23320
# 335390  02-08-2017 19:11          7140
# 335391  04-10-2017 19:46          5000
# 335392  04-08-2017 20:59         25000
# 335393  09-08-2017 19:43          2040
#
#                                                 HOSP_NAME HOSP_TYPE  \
# 0                 Rims Govt. General Hospital, Srikakulam         G
# 1                 Rims Govt. General Hospital, Srikakulam         G
# 2                 Rims Govt. General Hospital, Srikakulam         G
# 3                 Rims Govt. General Hospital, Srikakulam         G
# 4                 Rims Govt. General Hospital, Srikakulam         G
# ...                                                   ...       ...
# 335389                                Sankar Eye Hospital         C
# 335390  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...         C
# 335391                                    M.N.J.Hospitals         G
# 335392             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL         C
# 335393  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...         C
#
#             SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 0       06-08-2013 00:00  07-09-2013 00:00              NO            NaN
# 1       08-08-2013 00:00  09-09-2013 00:00              NO            NaN
# 2       15-08-2013 00:00  18-10-2013 00:00              NO            NaN
# 3       24-08-2013 00:00  27-09-2013 00:00              NO            NaN
# 4       31-08-2013 00:00  02-10-2013 00:00              NO            NaN
# ...                  ...               ...             ...            ...
# 335389  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335390  06-06-2017 00:00  06-06-2017 00:00              NO            NaN
# 335391  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335392  06-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335393  07-06-2017 00:00  07-06-2017 00:00              NO            NaN
#
#        SRC_REGISTRATION
# 0                     D
# 1                     D
# 2                     D
# 3                     D
# 4                     D
# ...                 ...
# 335389                D
# 335390                D
# 335391                D
# 335392                D
# 335393               MC
#
# [335394 rows x 17 columns]

# %%
#@title **To'g'ri javob**
df.drop(['Sno','CATEGORY_CODE','SURGERY_CODE','MANDAL_NAME','DISTRICT_NAME','HOSP_DISTRICT'],axis='columns',inplace=True)
df
# Out:
#         AGE     SEX CASTE_NAME             CATEGORY_NAME  \
# 0        56  Female         BC                NEPHROLOGY
# 1        37    Male         BC                NEPHROLOGY
# 2        50    Male         BC                NEPHROLOGY
# 3        45    Male         BC                NEPHROLOGY
# 4        54    Male         BC                NEPHROLOGY
# ...     ...     ...        ...                       ...
# 335389   65    Male         SC    OPHTHALMOLOGY  SURGERY
# 335390   54  Female         OC          MEDICAL ONCOLOGY
# 335391   19  Female         SC          MEDICAL ONCOLOGY
# 335392   50    Male         BC  GENITO URINARY SURGERIES
# 335393   46  Female         SC          MEDICAL ONCOLOGY
#
#                                                   SURGERY  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         VILLAGE      PREAUTH_DATE  PREAUTH_AMT  \
# 0                        Lolugu  03-08-2013 20:38        12500
# 1                     Borivanka  06-08-2013 07:26        12500
# 2                   Kapasakuddi  09-08-2013 18:30        12500
# 3                   Telikipenta  24-08-2013 19:37        12500
# 4                 Thandemvalasa  28-08-2013 17:03        12500
# ...                         ...               ...          ...
# 335389             Chintalapudi  08-06-2017 06:40        23320
# 335390  Udayagiri @ Kondayapale  05-06-2017 22:35         7140
# 335391                  Vinduru  06-06-2017 06:13         5000
# 335392                Duppituru  05-06-2017 23:37        25000
# 335393             Ananthavaram  06-06-2017 23:02         2040
#
#               CLAIM_DATE  CLAIM_AMOUNT  \
# 0       22-03-2017 20:25         11000
# 1       22-03-2017 20:25         11000
# 2       22-03-2017 20:25         11500
# 3       22-03-2017 20:25         11000
# 4       22-03-2017 20:25         11000
# ...                  ...           ...
# 335389  04-08-2017 21:23         23320
# 335390  02-08-2017 19:11          7140
# 335391  04-10-2017 19:46          5000
# 335392  04-08-2017 20:59         25000
# 335393  09-08-2017 19:43          2040
#
#                                                 HOSP_NAME HOSP_TYPE  \
# 0                 Rims Govt. General Hospital, Srikakulam         G
# 1                 Rims Govt. General Hospital, Srikakulam         G
# 2                 Rims Govt. General Hospital, Srikakulam         G
# 3                 Rims Govt. General Hospital, Srikakulam         G
# 4                 Rims Govt. General Hospital, Srikakulam         G
# ...                                                   ...       ...
# 335389                                Sankar Eye Hospital         C
# 335390  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...         C
# 335391                                    M.N.J.Hospitals         G
# 335392             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL         C
# 335393  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...         C
#
#             SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 0       06-08-2013 00:00  07-09-2013 00:00              NO            NaN
# 1       08-08-2013 00:00  09-09-2013 00:00              NO            NaN
# 2       15-08-2013 00:00  18-10-2013 00:00              NO            NaN
# 3       24-08-2013 00:00  27-09-2013 00:00              NO            NaN
# 4       31-08-2013 00:00  02-10-2013 00:00              NO            NaN
# ...                  ...               ...             ...            ...
# 335389  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335390  06-06-2017 00:00  06-06-2017 00:00              NO            NaN
# 335391  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335392  06-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335393  07-06-2017 00:00  07-06-2017 00:00              NO            NaN
#
#        SRC_REGISTRATION
# 0                     D
# 1                     D
# 2                     D
# 3                     D
# 4                     D
# ...                 ...
# 335389                D
# 335390                D
# 335391                D
# 335392                D
# 335393               MC
#
# [335394 rows x 17 columns]

# %% [markdown]
# #### **3-mashq**. Datasetdagi sex(jinsi) nomli qatordagi qiymatlarni unique funksiyasi orqali tekshiring.

# %%
# Javobni shuyerga yozing
df["SEX"].unique()
# Out:
# array(['Female', 'Male', 'Male(Child)', 'Female(Child)', 'FEMALE'],
#       dtype=object)

# %%
#@title **To'g'ri javob**
df["SEX"].unique()

# %% [markdown]
# #### **4-mashq**. Datasetdagi sex(jinsi) nomli qatordagi qiymatlarni **Erkak** va **Ayol** ga o'zgartiring:
# O'zgartirish quyidagicha bo'lsin:
#
#
# *   Male -> Erkak
# *   Male(child) -> Erkak
# *   Female - > Ayol
# *   Female(child) - Ayol
# *   MALE -> Erkak
# *   FEMALE -> Ayol

# %%
# Javobni shuyerga yozing

dict = {"Male":"Erkak","Male(child)":"Erkak", "Female":"Ayol","Female(child)":"Ayol","FEMALE":"Ayol"}
df["SEX"] = df["SEX"].map(dict)

# %%
#@title **To'g'ri javob**
dict = {"Male":"Erkak","Male(child)":"Erkak", "Female":"Ayol","Female(child)":"Ayol","MALE":"Erkak","FEMALE":"Ayol"}
df["SEX"] = df["SEX"].map(dict)

# %% [markdown]
# #### **5-mashq**. Endi xuddi shu SEX columndagi ma'lumotlarni raqamlarga o'zgartiring: Erkaklarni 1 raqamiga, Ayollarni 0 raqamiga o'zgartiring.
# *   Erkak -> 1
# *   Ayol -> 0

# %%
# Javobni shuyerga yozing
dict2 = {"Male":1,"Male(child)":1, "Female":0,"Female(child)":0,"FEMALE":0}
df["SEX"] = df["SEX"].map(dict2)
df.head()
# Out:
#    AGE  SEX CASTE_NAME CATEGORY_NAME                           SURGERY  \
# 0   56  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
# 1   37  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
# 2   50  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
# 3   45  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
# 4   54  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
#
#          VILLAGE      PREAUTH_DATE  PREAUTH_AMT        CLAIM_DATE  \
# 0         Lolugu  03-08-2013 20:38        12500  22-03-2017 20:25
# 1      Borivanka  06-08-2013 07:26        12500  22-03-2017 20:25
# 2    Kapasakuddi  09-08-2013 18:30        12500  22-03-2017 20:25
# 3    Telikipenta  24-08-2013 19:37        12500  22-03-2017 20:25
# 4  Thandemvalasa  28-08-2013 17:03        12500  22-03-2017 20:25
#
#    CLAIM_AMOUNT                                HOSP_NAME HOSP_TYPE  \
# 0         11000  Rims Govt. General Hospital, Srikakulam         G
# 1         11000  Rims Govt. General Hospital, Srikakulam         G
# 2         11500  Rims Govt. General Hospital, Srikakulam         G
# 3         11000  Rims Govt. General Hospital, Srikakulam         G
# 4         11000  Rims Govt. General Hospital, Srikakulam         G
#
#        SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 0  06-08-2013 00:00  07-09-2013 00:00              NO            NaN
# 1  08-08-2013 00:00  09-09-2013 00:00              NO            NaN
# 2  15-08-2013 00:00  18-10-2013 00:00              NO            NaN
# 3  24-08-2013 00:00  27-09-2013 00:00              NO            NaN
# 4  31-08-2013 00:00  02-10-2013 00:00              NO            NaN
#
#   SRC_REGISTRATION
# 0                D
# 1                D
# 2                D
# 3                D
# 4                D
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_2358178226392976676 = autoviz.get_registered_df('df_2358178226392976676')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_2358178226392976676, *['AGE'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_948914276208768210 = autoviz.get_registered_df('df_948914276208768210')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_948914276208768210, *['CLAIM_AMOUNT'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5788710547181504218 = autoviz.get_registered_df('df_5788710547181504218')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_5788710547181504218, *['AGE'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_9081925181001828814 = autoviz.get_registered_df('df_9081925181001828814')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_9081925181001828814, *['CLAIM_AMOUNT'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8455351182463209853 = autoviz.get_registered_df('df_8455351182463209853')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_8455351182463209853, *['VILLAGE'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3918223723006914366 = autoviz.get_registered_df('df_3918223723006914366')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_3918223723006914366, *[[['AGE', 'CLAIM_AMOUNT']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1619464343545591597 = autoviz.get_registered_df('df_1619464343545591597')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_1619464343545591597, *['AGE', 'VILLAGE'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8733444638740272713 = autoviz.get_registered_df('df_8733444638740272713')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_8733444638740272713, *['CLAIM_AMOUNT', 'VILLAGE'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_7882601443972006729 = autoviz.get_registered_df('df_7882601443972006729')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_7882601443972006729, *['PREAUTH_DATE', 'AGE', 'VILLAGE'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3547369609617426650 = autoviz.get_registered_df('df_3547369609617426650')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_3547369609617426650, *['PREAUTH_DATE', 'CLAIM_AMOUNT', 'VILLAGE'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6468825657765874988 = autoviz.get_registered_df('df_6468825657765874988')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_6468825657765874988, *['PREAUTH_DATE', 'count()', 'VILLAGE'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5172057420164200906 = autoviz.get_registered_df('df_5172057420164200906')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_5172057420164200906, *['SURGERY_DATE', 'AGE', 'VILLAGE'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5098440938208912399 = autoviz.get_registered_df('df_5098440938208912399')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_5098440938208912399, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5552654574242910023 = autoviz.get_registered_df('df_5552654574242910023')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_5552654574242910023, *['AGE'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2325112380821700407 = autoviz.get_registered_df('df_2325112380821700407')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_2325112380821700407, *['CLAIM_AMOUNT'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8480580192296621312 = autoviz.get_registered_df('df_8480580192296621312')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_8480580192296621312, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2112225314128233073 = autoviz.get_registered_df('df_2112225314128233073')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2112225314128233073, *['AGE'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3739995896639179521 = autoviz.get_registered_df('df_3739995896639179521')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3739995896639179521, *['CLAIM_AMOUNT'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_2142251384319713733 = autoviz.get_registered_df('df_2142251384319713733')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_2142251384319713733, *['VILLAGE'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3704261722781991732 = autoviz.get_registered_df('df_3704261722781991732')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_3704261722781991732, *[[['index', 'AGE'], ['AGE', 'CLAIM_AMOUNT']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_9081553223788338494 = autoviz.get_registered_df('df_9081553223788338494')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_9081553223788338494, *['index', 'VILLAGE'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1108066705694321492 = autoviz.get_registered_df('df_1108066705694321492')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_1108066705694321492, *['AGE', 'VILLAGE'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2620449930503116144 = autoviz.get_registered_df('df_2620449930503116144')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_2620449930503116144, *['CLAIM_AMOUNT', 'VILLAGE'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5604621779687970721 = autoviz.get_registered_df('df_5604621779687970721')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_5604621779687970721, *['PREAUTH_DATE', 'AGE', 'VILLAGE'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3089705743937206425 = autoviz.get_registered_df('df_3089705743937206425')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_3089705743937206425, *['PREAUTH_DATE', 'CLAIM_AMOUNT', 'VILLAGE'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8219865109743419838 = autoviz.get_registered_df('df_8219865109743419838')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_8219865109743419838, *['PREAUTH_DATE', 'count()', 'VILLAGE'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2114638918273734311 = autoviz.get_registered_df('df_2114638918273734311')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_2114638918273734311, *['SURGERY_DATE', 'AGE', 'VILLAGE'], **{})
# chart

# %%
#@title **To'g'ri javob**
dict2 = {'Erkak':1, 'Ayol':0}
df["SEX"] = df["SEX"].map(dict2)
df.head(5)
# Out:
#    AGE  SEX CASTE_NAME CATEGORY_NAME                           SURGERY  \
# 0   56  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
# 1   37  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
# 2   50  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
# 3   45  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
# 4   54  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
#
#          VILLAGE      PREAUTH_DATE  PREAUTH_AMT        CLAIM_DATE  \
# 0         Lolugu  03-08-2013 20:38        12500  22-03-2017 20:25
# 1      Borivanka  06-08-2013 07:26        12500  22-03-2017 20:25
# 2    Kapasakuddi  09-08-2013 18:30        12500  22-03-2017 20:25
# 3    Telikipenta  24-08-2013 19:37        12500  22-03-2017 20:25
# 4  Thandemvalasa  28-08-2013 17:03        12500  22-03-2017 20:25
#
#    CLAIM_AMOUNT                                HOSP_NAME HOSP_TYPE  \
# 0         11000  Rims Govt. General Hospital, Srikakulam         G
# 1         11000  Rims Govt. General Hospital, Srikakulam         G
# 2         11500  Rims Govt. General Hospital, Srikakulam         G
# 3         11000  Rims Govt. General Hospital, Srikakulam         G
# 4         11000  Rims Govt. General Hospital, Srikakulam         G
#
#        SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 0  06-08-2013 00:00  07-09-2013 00:00              NO            NaN
# 1  08-08-2013 00:00  09-09-2013 00:00              NO            NaN
# 2  15-08-2013 00:00  18-10-2013 00:00              NO            NaN
# 3  24-08-2013 00:00  27-09-2013 00:00              NO            NaN
# 4  31-08-2013 00:00  02-10-2013 00:00              NO            NaN
#
#   SRC_REGISTRATION
# 0                D
# 1                D
# 2                D
# 3                D
# 4                D

# %% [markdown]
# #### **6-mashq**. Shu jarayonni HOSP_TYPE ustuni uchun ham amalga oshiring.
# *   G - General hospital (umumiy kasalxona) degani
# *   C - Special hospital (maxsus kasalxona) degani
# <br><b>O'zgarish quyidagicha bo'lsin:</b>
# *   G -> Umumiy
# *   C -> Maxsus

# %%
# Javobni shuyerga yozing

dict3 = {'G':'Umumiy', 'C':'Maxsus'}
df["HOSP_TYPE"] = df["HOSP_TYPE"].map(dict3)
df.head(5)
# Out:
#    AGE  SEX CASTE_NAME CATEGORY_NAME                           SURGERY  \
# 0   56  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
# 1   37  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
# 2   50  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
# 3   45  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
# 4   54  NaN         BC    NEPHROLOGY  Maintenance Hemodialysis For Crf
#
#          VILLAGE      PREAUTH_DATE  PREAUTH_AMT        CLAIM_DATE  \
# 0         Lolugu  03-08-2013 20:38        12500  22-03-2017 20:25
# 1      Borivanka  06-08-2013 07:26        12500  22-03-2017 20:25
# 2    Kapasakuddi  09-08-2013 18:30        12500  22-03-2017 20:25
# 3    Telikipenta  24-08-2013 19:37        12500  22-03-2017 20:25
# 4  Thandemvalasa  28-08-2013 17:03        12500  22-03-2017 20:25
#
#    CLAIM_AMOUNT                                HOSP_NAME HOSP_TYPE  \
# 0         11000  Rims Govt. General Hospital, Srikakulam    Umumiy
# 1         11000  Rims Govt. General Hospital, Srikakulam    Umumiy
# 2         11500  Rims Govt. General Hospital, Srikakulam    Umumiy
# 3         11000  Rims Govt. General Hospital, Srikakulam    Umumiy
# 4         11000  Rims Govt. General Hospital, Srikakulam    Umumiy
#
#        SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 0  06-08-2013 00:00  07-09-2013 00:00              NO            NaN
# 1  08-08-2013 00:00  09-09-2013 00:00              NO            NaN
# 2  15-08-2013 00:00  18-10-2013 00:00              NO            NaN
# 3  24-08-2013 00:00  27-09-2013 00:00              NO            NaN
# 4  31-08-2013 00:00  02-10-2013 00:00              NO            NaN
#
#   SRC_REGISTRATION
# 0                D
# 1                D
# 2                D
# 3                D
# 4                D

# %%
#@title **To'g'ri javob**
df["HOSP_TYPE"] = df["HOSP_TYPE"].map({'G':"Umumiy", 'C':"Maxsus"})

# %% [markdown]
# #### **7-mashq**. O'zgartirish amalga oshirilgach, HOSP_TYPE ustunida qancha Umumiy va qancha Maxsus kasalxonalar borligini ham aniqlang

# %%
# Javobni shuyerga yozing
df["HOSP_TYPE"].value_counts()
# Out:
# Maxsus    241139
# Umumiy     94255
# Name: HOSP_TYPE, dtype: int64

# %%
#@title **To'g'ri javob**
df["HOSP_TYPE"].value_counts()

# %% [markdown]
# #### **8-mashq**. Datasetda qancha takrorlangan qatorlar borligini aniqlang

# %%
# Javobni shuyerga yozing

sum(df.duplicated())
# Out:
# 32

# %%
#@title **To'g'ri javob**
sum(df.duplicated())

# %% [markdown]
# #### **9-mashq**. Datasetda barcha takrorlangan qatorlarni o'chirib yuboring

# %%
# Javobni shuyerga yozing

df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of         AGE  SEX CASTE_NAME             CATEGORY_NAME  \
# 0        56  NaN         BC                NEPHROLOGY
# 1        37  NaN         BC                NEPHROLOGY
# 2        50  NaN         BC                NEPHROLOGY
# 3        45  NaN         BC                NEPHROLOGY
# 4        54  NaN         BC                NEPHROLOGY
# ...     ...  ...        ...                       ...
# 335389   65  NaN         SC    OPHTHALMOLOGY  SURGERY
# 335390   54  NaN         OC          MEDICAL ONCOLOGY
# 335391   19  NaN         SC          MEDICAL ONCOLOGY
# 335392   50  NaN         BC  GENITO URINARY SURGERIES
# 335393   46  NaN         SC          MEDICAL ONCOLOGY
#
#                                                   SURGERY  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         VILLAGE      PREAUTH_DATE  PREAUTH_AMT  \
# 0                        Lolugu  03-08-2013 20:38        12500
# 1                     Borivanka  06-08-2013 07:26        12500
# 2                   Kapasakuddi  09-08-2013 18:30        12500
# 3                   Telikipenta  24-08-2013 19:37        12500
# 4                 Thandemvalasa  28-08-2013 17:03        12500
# ...                         ...               ...          ...
# 335389             Chintalapudi  08-06-2017 06:40        23320
# 335390  Udayagiri @ Kondayapale  05-06-2017 22:35         7140
# 335391                  Vinduru  06-06-2017 06:13         5000
# 335392                Duppituru  05-06-2017 23:37        25000
# 335393             Ananthavaram  06-06-2017 23:02         2040
#
#               CLAIM_DATE  CLAIM_AMOUNT  \
# 0       22-03-2017 20:25         11000
# 1       22-03-2017 20:25         11000
# 2       22-03-2017 20:25         11500
# 3       22-03-2017 20:25         11000
# 4       22-03-2017 20:25         11000
# ...                  ...           ...
# 335389  04-08-2017 21:23         23320
# 335390  02-08-2017 19:11          7140
# 335391  04-10-2017 19:46          5000
# 335392  04-08-2017 20:59         25000
# 335393  09-08-2017 19:43          2040
#
#                                                 HOSP_NAME HOSP_TYPE  \
# 0                 Rims Govt. General Hospital, Srikakulam    Umumiy
# 1                 Rims Govt. General Hospital, Srikakulam    Umumiy
# 2                 Rims Govt. General Hospital, Srikakulam    Umumiy
# 3                 Rims Govt. General Hospital, Srikakulam    Umumiy
# 4                 Rims Govt. General Hospital, Srikakulam    Umumiy
# ...                                                   ...       ...
# 335389                                Sankar Eye Hospital    Maxsus
# 335390  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...    Maxsus
# 335391                                    M.N.J.Hospitals    Umumiy
# 335392             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL    Maxsus
# 335393  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...    Maxsus
#
#             SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 0       06-08-2013 00:00  07-09-2013 00:00              NO            NaN
# 1       08-08-2013 00:00  09-09-2013 00:00              NO            NaN
# 2       15-08-2013 00:00  18-10-2013 00:00              NO            NaN
# 3       24-08-2013 00:00  27-09-2013 00:00              NO            NaN
# 4       31-08-2013 00:00  02-10-2013 00:00              NO            NaN
# ...                  ...               ...             ...            ...
# 335389  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335390  06-06-2017 00:00  06-06-2017 00:00              NO            NaN
# 335391  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335392  06-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335393  07-06-2017 00:00  07-06-2017 00:00              NO            NaN
#
#        SRC_REGISTRATION
# 0                     D
# 1                     D
# 2                     D
# 3                     D
# 4                     D
# ...                 ...
# 335389                D
# 335390                D
# 335391                D
# 335392                D
# 335393               MC
#
# [335394 rows x 17 columns]>

# %%
#@title **To'g'ri javob**
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### **10-mashq**. Datasetdan shifoxona turiga ko'ra (umumiy va maxsus), ClAIM_AMOUNTning o'rtacha qiymatlarini toping.

# %%
# Javobni shuyerga yozing
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.mean()
# Out:
# HOSP_TYPE
# Maxsus    30275.151848
# Umumiy    22683.614852
# Name: CLAIM_AMOUNT, dtype: float64

# %%
#@title **To'g'ri javob**
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.mean()

# %% [markdown]
# #### **11-mashq**. Datasetdan shifoxona turiga ko'ra (umumiy va maxsus), ClAIM_AMOUNTning minimum qiymatlarini toping.

# %%
# Javobni shuyerga yozing
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.min()
# Out:
# HOSP_TYPE
# Maxsus    2
# Umumiy    2
# Name: CLAIM_AMOUNT, dtype: int64

# %%
#@title **To'g'ri javob**
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.min()

# %% [markdown]
# #### **12-mashq**. Datasetdan shifoxona turiga ko'ra (umumiy va maxsus), CLAIM_AMOUNTning maksimum qiymatlarini toping.

# %%
# Javobni shuyerga yozing
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.max()
# Out:
# HOSP_TYPE
# Maxsus    520000
# Umumiy    520000
# Name: CLAIM_AMOUNT, dtype: int64

# %%
#@title **To'g'ri javob**
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.max()

# %% [markdown]
# .agg() yordamida istalgan funksiyalarni chaqirishimiz mumkin, misol uchun numpy dagi mean (o'rta qiymat) funiksiyasini ham qo'shamiz. Natijalarni faqat price ustuni uchun chiqaramiz:

# %% [markdown]
# #### **13-mashq**. Datasetdan jinsiga ko'ra CLAIM_AMOUNTning min, max va o'rta qiymatlarni agg() usuli yordamida toping.

# %%
# Javobni shuyerga yozing

df.groupby('SEX').CLAIM_AMOUNT.agg([min, max, np.mean])
# Out:
# Empty DataFrame
# Columns: [min, max, mean]
# Index: []

# %%
#@title **To'g'ri javob**
df.groupby('SEX').CLAIM_AMOUNT.agg([min, max, np.mean])
# Out:
# Empty DataFrame
# Columns: [min, max, mean]
# Index: []
