# %%
import numpy as np

# %%
my_list = list(range(100000)) # python list 0~99999 -->Normal
my_array = np.array(range(100000)) # numpy array(massiv) 0~99999 --> Vektorlashgan

# %%
# %time for _ in range(20): [x*2 for x in my_list] # Normal
# Out:
# CPU times: user 117 ms, sys: 23.4 ms, total: 141 ms
# Wall time: 204 ms

# %%
# %time for _ in range(20): my_array*2
# Out:
# CPU times: user 3.19 ms, sys: 0 ns, total: 3.19 ms
# Wall time: 4.94 ms

# %%
204/4.94
# Out:
# 41.29554655870445
